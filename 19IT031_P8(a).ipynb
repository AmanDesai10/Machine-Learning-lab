# %% [markdown]
# ## `19IT031 Aman Desai`
#
# ## Practical - 8(a) `SVM Plot using Seaborn`

# %%
import numpy as np
from sklearn.svm import SVC
import matplotlib.pyplot as plt
import sklearn.datasets
from sklearn import datasets
import pandas as pd
import seaborn as sn

# %% [markdown]
# ### plot synthetic data using seaborn

# %%
X, y = sklearn.datasets.make_blobs(n_samples=300, centers=2, random_state=7)
sn.scatterplot(X[:, 0], X[:, 1], c=y, edgecolor="b")
print(X.shape,y.shape)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# (300, 2) (300,)

# %% [markdown]
# There are different type of kernel like 'linear', 'poly', 'rbf', 'sigmoid' and 'precomputed', for given dataset the linear gives best fit so
# it was used.
# Find the dataset which is considered to be real observations.
# Apply SVM to classify selected dataset and plot graph using seaborn.

# %%
df = pd.read_csv('suv_data.csv')
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.drop('User ID', axis=1, inplace=True)
df.drop('Gender', axis=1, inplace=True)

# %%
X = df.drop('Purchased', axis=1)
Y = df.Purchased

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.25, random_state = 0)

# %%
print(x_train.shape)
print(x_test.shape)
# Out:
# (300, 2)
# (100, 2)

# %%
model=SVC(C=0.15)

# %%
model.fit(x_train,y_train)
# Out:
# SVC(C=0.15)

# %%
model.score(x_test,y_test)
# Out:
# 0.79

# %%
y_predict=model.predict(x_test)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_predict)

# %%
import seaborn as sn
sn.heatmap(cm,annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(33.0, 0.5, 'Truth')

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# %%
df = pd.DataFrame(iris.data,columns=iris.feature_names)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
df['target'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df['flower_name'] =df.target.apply(lambda x: iris.target_names[x])
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target flower_name
# 0       0      setosa
# 1       0      setosa
# 2       0      setosa
# 3       0      setosa
# 4       0      setosa

# %%
df0 = df[:50]
df1 = df[50:100]
df2 = df[100:]

# %%
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
sn.scatterplot(df0['sepal length (cm)'], df0['sepal width (cm)'],color="red")
sn.scatterplot(df1['sepal length (cm)'], df1['sepal width (cm)'],color="blue")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
sn.scatterplot(df0['petal length (cm)'], df0['petal width (cm)'],color="black")
sn.scatterplot(df1['petal length (cm)'], df1['petal width (cm)'],color="blue")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['target','flower_name'], axis='columns')
y = df.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model.fit(X_train, y_train)
# Out:
# SVC(C=0.15)

# %%
model.score(X_test, y_test)
# Out:
# 0.9333333333333333

# %%
Y_predict=model.predict(X_test)
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,Y_predict)

# %%
sn.heatmap(cm,annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(33.0, 0.5, 'Truth')

# %% [markdown]
# ### Conclusion:
# By performing this practical  i learned about SVM (Support Vector Machine) classifier to classifies iris data and suv car data and plotted
# graph of it.
